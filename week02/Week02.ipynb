# %% [markdown]
# # Week 02: the beginnings of data structures
#
#
# - Functions for `contains`, `index_of`, `index_of_all` etc on a simple list.
# - Functions for `add`, `add_unique`, `remove_first`, and `remove_all` on a simple list.
#
# ## Reading
#
# - [Lists in Python](https://learning.oreilly.com/library/view/introducing-python-3rd/9781098174392/ch08.html#c08_h_list_create) from Bill Lubanovic's _Introducing Python,_ 3rd edition (free access on the O'Reilly platform using your LUC email).
# - [Python technical reference about lists](https://docs.python.org/3/library/stdtypes.html#typesseq-list).
# - [Python technical reference about list operations](https://docs.python.org/3/tutorial/datastructures.html#more-on-lists).
# - [Loops in Python](https://learning.oreilly.com/library/view/introducing-python-3rd/9781098174392/ch07.html) from Bill Lubanovic's _Introducing Python,_ 3rd edition (free access on the O'Reilly platform using your LUC email).
# - [Python technical reference about `for` loops](https://docs.python.org/3/tutorial/controlflow.html#for-statements).
#
#
# ## Practice
#
# Set of [practice problems](https://leetcode.com/problem-list/w91gvfl5/) on LeetCode.
#
# ## Assignment
#
# To be posted.
