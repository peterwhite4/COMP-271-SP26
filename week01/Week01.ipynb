# %% [markdown]
# # Week 01: Building on prior programming knowledge.
#
# - The House that Jack Built: a simple Python program illustrating basic programming constructs.
# - Mississippi in block letters, _horizontally._
# - The tools of the trade: GitHub Codespaces, Jupyter Notebooks, and _MarkDown._
# - Is El alive?
# - The Programmer's Pact. Oral exams and final exam.
#
# ## Reading
#
# - [Lists in Python](https://learning.oreilly.com/library/view/introducing-python-3rd/9781098174392/ch08.html#c08_h_list_create) from Bill Lubanovic's _Introducing Python,_ 3rd edition (free access on the O'Reilly platform using your LUC email).
# - [Loops in Python](https://learning.oreilly.com/library/view/introducing-python-3rd/9781098174392/ch07.html) from Bill Lubanovic's _Introducing Python,_ 3rd edition (free access on the O'Reilly platform using your LUC email).
# - [Functions in Python](https://learning.oreilly.com/library/view/introducing-python-3rd/9781098174392/ch10.html) from Bill Lubanovic's _Introducing Python,_ 3rd edition (free access on the O'Reilly platform using your LUC email).
# - [f-strings in Python](https://learning.oreilly.com/library/view/introducing-python-3rd/9781098174392/ch04.html#c04_h_fstring) from Bill Lubanovic's _Introducing Python,_ 3rd edition (free access on the O'Reilly platform using your LUC email).
# - [Cumulative tales](https://en.wikipedia.org/wiki/Cumulative_tale) from Wikipedia.
#
# ## Practice
#
# Set of [practice problems](https://leetcode.com/problem-list/w91z6871/) on LeetCode.
#
# ## Assignment
#
# [Posted](https://github.com/lgreco/COMP-271-SP26/blob/main/week01/assignment.ipynb).

# %% [markdown]
# ## Review of problems from COMP 170
#
# The House that Jack Build and printing Mississipi in block letters were two early assignments in COMP 170. We revisit them here, executing them with more advanced techniques than were available at the time of their assignment in the introductory course.
#
# ---
#
# ### The House That Jack Built
#
# An assigment early on in COMP 170 asks to write code for each stanza of the nursery rhyme:
#
# ```text
#    This is the house that Jack built.
#
#    This is the malt that lay in the house that Jack built.
#
#    This is the rat that ate the malt
#    That lay in the house that Jack built.
#
#    This is the cat
#    That killed the rat that ate the malt
#    That lay in the house that Jack built.
#
#    This is the dog that worried the cat
#    That killed the rat that ate the malt
#    That lay in the house that Jack built.
#
#    This is the cow with the crumpled horn
#    That tossed the dog that worried the cat
#    That killed the rat that ate the malt
#    That lay in the house that Jack built.
# ```
#
# A simple approach to this problem is shown below.

# %%
def house():
    print("This is the house that Jack built.")


def malt():
    print("This is the malt that lay in the house that Jack built.")


def rat():
    print("This is the rat that ate the malt")
    print("That lay in the house that Jack built.")


def cat():
    print("This is the cat")
    print("That killed the rat that ate the malt")
    print("That lay in the house that Jack built.")


def dog():
    print("This is the dog that worried the cat")
    print("That killed the rat that ate the malt")
    print("That lay in the house that Jack built.")


def cow():
    print("This is the cow with the crumpled horn")
    print("That tossed the dog that worried the cat")
    print("That killed the rat that ate the malt")
    print("That lay in the house that Jack built.")


def main():
    house()
    print()
    malt()
    print()
    rat()
    print()
    cat()
    print()
    dog()
    print()
    cow()


main()

# %% [markdown]
# With a bit more effort, the code can be "improved" to the following.

# %%
def house():
    print("That lay in the house that Jack built.")


def malt_tail():
    print("the malt")
    house()


def rat_tail():
    print("the rat that ate the malt")
    house()


def cat_tail():
    print("the cat")
    print("That killed the rat that ate the malt")
    house()


def dog_tail():
    print("the dog that worried the cat")
    print("That killed the rat that ate the malt")
    house()


def cow_tail():
    print("the cow with the crumpled horn")
    print("That tossed the dog that worried the cat")
    print("That killed the rat that ate the malt")
    house()


def house_verse():
    print("This is the house that Jack built.")


def malt_verse():
    print("This is the malt that lay in")
    house()


def rat_verse():
    print("This is the rat that ate")
    malt_tail()


def cat_verse():
    print("This is")
    cat_tail()


def dog_verse():
    print("This is")
    dog_tail()


def cow_verse():
    print("This is")
    cow_tail()


def main():
    house_verse()
    print()
    malt_verse()
    print()
    rat_verse()
    print()
    cat_verse()
    print()
    dog_verse()
    print()
    cow_verse()


main()

# %% [markdown]
# This is just about as good as it gets with the basic skills aquired early in an introductory course. The code can be improved a little bit by introducing constants as shown below.

# %%
PREFIX = "This is"

HOUSE_TAIL = "the house that Jack built."
MALT_TAIL = "the malt that lay in " + HOUSE_TAIL
RAT_TAIL = "the rat that ate\n" + MALT_TAIL
CAT_TAIL = "the cat \nThat killed " + RAT_TAIL
DOG_TAIL = "the dog that worried " + CAT_TAIL
COW_TAIL = "the cow with the crumpled horn \nThat tossed " + DOG_TAIL

def house_verse():
    print(PREFIX, HOUSE_TAIL)

def malt_verse():
    print(PREFIX, MALT_TAIL)

def rat_verse():
    print(PREFIX, RAT_TAIL)

def cat_verse():
    print(PREFIX, CAT_TAIL)

def dog_verse():
    print(PREFIX, DOG_TAIL)

def cow_verse():
    print(PREFIX, COW_TAIL)

def main():
    house_verse()
    print()
    malt_verse()
    print()
    rat_verse()
    print()
    cat_verse()
    print()
    dog_verse()
    print()
    cow_verse()


main()

# %% [markdown]
# Still, we are writing repeatitive code. One way to improve the solution for the nursery rhyme, is with lists. We learned about lists in introductory programming after the nursery rhyme assignment, so let's try them now, here.
#
# We start with some (really bad) code introducing lists and hard-coded indices, in the earlier program with the `print` statements.

# %%
# Use lists of strings to deliver the nursery rhyme.

PREFIX = "This is the"
SUFFIX = "house that Jack built."

ITEMS = ["", "malt", "rat", "cat", "dog"]
ACTIONS = ["", "lay", "ate", "killed", "worried"]


def house():
    print(f"{PREFIX} {SUFFIX}")


def malt():
    print(f"{PREFIX} {ITEMS[1]} that {ACTIONS[1]} in the {SUFFIX}")


def rat():
    print(
        f"{PREFIX} {ITEMS[2]} that {ACTIONS[2]} the {ITEMS[1]} that {ACTIONS[1]} in the {SUFFIX}"
    )


def cat():
    print(
        f"{PREFIX} {ITEMS[3]} that {ACTIONS[3]} the {ITEMS[2]} that {ACTIONS[2]} the {ITEMS[1]} that {ACTIONS[1]} in the {SUFFIX}"
    )


def dog():
    print(
        f"{PREFIX} {ITEMS[4]} that {ACTIONS[4]} the {ITEMS[3]} that {ACTIONS[3]} the {ITEMS[2]} that {ACTIONS[2]} the {ITEMS[1]} that {ACTIONS[1]} in the {SUFFIX}"
    )


house()
print()
malt()
print()
rat()
print()
cat()
print()
dog()

# %% [markdown]
# The code above reveals a pattern that we can exploit further. Focusing on what is printed in the `cat()` method and its previous method (`rat()`) we can rewritte the code as
#
# ```python
# rat_string = f"{ITEMS[2]} that {ACTIONS[2]} the {ITEMS[1]} that {ACTIONS[1]} in the {SUFFIX}"
# cat_string = f"{ITEMS[3]} that {ACTIONS[3]} the {rat_string}"
#
# def rat():
#     print f"{PREFIX} {rat_string}"
# def cat():
#     print f"{PREFIX} {cat_string}"
# ```
#
# Then, we might notice that the `rat_string` contains part of the previous method's output. And that in general every method is built on content from the previous method.

# %%
PREFIX = "This is the"
SUFFIX = "house that Jack built."

ITEMS = ["", "malt", "rat", "cat", "dog"]
ACTIONS = ["", "lay", "ate", "killed", "worried"]

malt_string = f"{ITEMS[1]} that {ACTIONS[1]} in the {SUFFIX}"
rat_string = f"{ITEMS[2]} that {ACTIONS[2]} the {malt_string}"
cat_string = f"{ITEMS[3]} that {ACTIONS[3]} the {rat_string}"
dog_string = f"{ITEMS[4]} that {ACTIONS[4]} the {cat_string}"


def house():
    print(f"{PREFIX} {SUFFIX}")


def malt():
    print(f"{PREFIX} {malt_string}")


def rat():
    print(f"{PREFIX} {rat_string}")


def cat():
    print(f"{PREFIX} {cat_string}")


def dog():
    print(f"{PREFIX} {dog_string}")


house()
print()
malt()
print()
rat()
print()
cat()
print()
dog()

# %% [markdown]
# Now we can see a broader pattern emerging and we can exploit it. The most obvious thing is that methods `malt()`, `rat()`, etc, can be replaced with a single method:
#
# ```python
# def print_stanza(item_string):
#     print(f"{PREFIX} {item_string}\n")
# ```
#
# The escape character `\n` above eliminates the need for an empty `print` after each method call.
#
# The next thing to notice is that the various item strings (`malt_string`, `rat_string`, etc) can be generated with a loop iterating over lists `ITEMS` and `ACTIONS`.
#
# Finally, the whole problem can be reduced to just two methods, and four constants as shown below.

# %%
PREFIX = "This is the"
SUFFIX = "house that Jack built."
CONNECTOR = "that"

ITEMS = ["", "malt", "rat", "cat", "dog"]
ACTIONS = ["", "lay", "ate", "killed", "worried"]


def first_stanza():
    # The very first stanza is special: it uses SUFFIX directly.
    print(f"{PREFIX} {SUFFIX}\n")


def other_stanzas():
    # Build each “item that action ...” string from the inside out.
    # Example:
    #   malt -> "malt that lay in the house that Jack built."
    #   rat  -> "rat that ate the malt that lay in the house that Jack built."
    prev = f"{SUFFIX}"  # what comes after "in the" for malt, and gets nested thereafter

    for i in range(1, len(ITEMS)):
        if i == 1:
            # malt is the only one that says "lay in the ..."
            current = f"{ITEMS[i]} {CONNECTOR} {ACTIONS[i]} in the {prev}"
        else:
            # everything else says "... the <previous phrase>"
            current = f"{ITEMS[i]} {CONNECTOR} {ACTIONS[i]} the {prev}"

        print(f"{PREFIX} {current}\n")
        prev = current


first_stanza()
other_stanzas()

# %% [markdown]
# There are still couple of improvements that can be made -- such as eliminating some magic values, but this is pretty good for now. Everything in the code above is done with techniques covered in COMP 170. The most important part in the analysis is to realize the cumulative nature of the nursery rhyme and find the best way to code it in the program itself.

# %% [markdown]
# ---
#
# ### Mississippi
#
# This was another early exercise in introductory programming. Write a program to print the name of the longest river in the US, in block letters, vertically. The code, expected for this assignment, is shown below.

# %%
def m():
    print(" M       M")
    print(" M M   M M")
    print(" M  M M  M")
    print(" M   M   M")
    print(" M       M")
    print(" M       M")
    print()


def i():
    print("     I    ")
    print("     I    ")
    print("     I    ")
    print("     I    ")
    print("     I    ")
    print("     I    ")
    print()


def s():
    print("   SSSSSSS")
    print(" SS       ")
    print(" SS       ")
    print("  SSSSSS  ")
    print("        SS")
    print("        SS")
    print(" SSSSSSS  ")
    print()


def p():
    print(" PPPPPPPP ")
    print(" P      PP")
    print(" P     PP ")
    print(" PPPPPP   ")
    print(" P        ")
    print(" P        ")
    print(" P        ")
    print()


def ssi():
    s()
    s()
    i()


def ssissi():
    ssi()
    ssi()


def pp():
    p()
    p()


def mississippi():
    m()
    i()
    ssissi()
    pp()
    i()


def main():
    mississippi()


main()

# %% [markdown]
# A nice variation to this problem is to print the name of the big river, in block letters, horizontally. To achieve that, first we must convert the block letters from print methods into lists of strings.

# %%
M = [
    " M       M",
    " M M   M M",
    " M  M M  M",
    " M   M   M",
    " M       M",
    " M       M",
    " M       M",
]

I = [
    "     I    ",
    "     I    ",
    "     I    ",
    "     I    ",
    "     I    ",
    "     I    ",
    "     I    ",
]

S = [
    "   SSSSSSS",
    " SS       ",
    " SS       ",
    "  SSSSSS  ",
    "        SS",
    "        SS",
    " SSSSSSS  ",
]

P = [
    " PPPPPPPP ",
    " P      PP",
    " P     PP ",
    " PPPPPP   ",
    " P        ",
    " P        ",
    " P        "
]

# %% [markdown]
# Using this abstraction, the vertical printing can be accomplished as follows.

# %%
def print_vertical(block_letter):
    for line in block_letter:
        print(line)
    print()


def compose_vertical(letters):
    for letter in letters:
        print_vertical(letter)


big_river = [M, I, S, S, I, S, S, I, P, I]
compose_vertical(big_river)

# %% [markdown]
# But we are not interested in vertical printing anymore. We want to display the name horizontally.

# %%
def compose_horizontal(letters):
    # Assume that each letter has the same height
    height = len(letters[0])
    # For each line from top to bottom of a block letter
    for line in range(height):
        # print that line for each letter
        for letter in letters:
            # Do not braak line for each letter (end="")
            print(letter[line], end ="")
        # Break a line after each letter has been processed at this line level
        print()


big_river = [M, I, S, S, I, S, S, I, P, I]
compose_horizontal(big_river)

# %% [markdown]
# The output, of course is not very pleasant -- that's because of two issues. First our block letters are not very neatly designed. Second, we are printing monospaced letters and it shows. These two issues are, in fact, opportunities to improve our code a bit. All it takes, really, is less empty space around the letter `I`:

# %%
I = [
    "  I ",
    "  I ",
    "  I ",
    "  I ",
    "  I ",
    "  I ",
    "  I ",
]

big_river = [M, I, S, S, I, S, S, I, P, I]
compose_horizontal(big_river)
